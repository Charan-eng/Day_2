# %%
name=input("please enter your name")
# Out:
# please enter your name charan

# %%
name
# Out:
# ' charan'

# %%
num1=input("please enter first no:")
# Out:
# please enter first no:15

# %%
num2=input("please enter second no no:")
# Out:
# please enter second no no:20

# %%
result = num1 + num2

# %%
result
# Out:
# '2020'

# %%
num1=int(input("please enter first no:"))
num2=int(input("please enter second no no:"))
result = num1 + num2
result
# Out:
# please enter first no:12
# please enter second no no:122
# 134

# %%
num=eval(input("enter the number:"))
# Out:
# enter the number:12345

# %%
type(num)
# Out:
# int

# %%
num=int(input("enter the number"))
result="number is even" if num%2==0 else "number is odd"
print(result)
# Out:
# enter the number999
# number is odd
